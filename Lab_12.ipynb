# %% [markdown]
# # **Laboratorio 12: 🚀 Despliegue 🚀**
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos</strong></center>
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Sebastian Tinoco
# - Auxiliar: Catherine Benavides, Consuelo Rojas
# - Ayudante: Eduardo Moya, Nicolás Ojeda

# %% [markdown]
# ### Equipo:
#
# - Pía Antiquera
# - Evelyn Silva
#
# ### **Link de repositorio de GitHub:** `https://github.com/piaantiquera/Courses-MDS7202.git`

# %% [markdown]
# ## Temas a tratar
#
# - Entrenamiento y registro de modelos usando MLFlow.
# - Despliegue de modelo usando FastAPI
# - Containerización del proyecto usando Docker
#
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Prohibidas las copias.
# - Pueden usar cualquer matrial del curso que estimen conveniente.
#
# ### Objetivos principales del laboratorio
#
# - Generar una solución a un problema a partir de ML
# - Desplegar su solución usando MLFlow, FastAPI y Docker
#
# El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `pandas`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre DataFrames.

# %% [markdown]
# # **Introducción**

# %% [markdown]
# <p align="center">
#   <img src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExODJnMHJzNzlkNmQweXoyY3ltbnZ2ZDlxY2c0aW5jcHNzeDNtOXBsdCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/AbPdhwsMgjMjax5reo/giphy.gif" width="400">
# </p>

# %% [markdown]
# Consumida en la tristeza el despido de Renacín, Smapina ha decaído en su desempeño, lo que se ha traducido en un irregular tratamiento del agua. Esto ha implicado una baja en la calidad del agua, llegando a haber algunos puntos de la comuna en la que el vital elemento no es apto para el consumo humano. Es por esto que la sanitaria pública de la municipalidad de Maipú se ha contactado con ustedes para que le entreguen una urgente solución a este problema (a la vez que dejan a Smapina, al igual que Renacín, sin trabajo 😔).
#
# El problema que la empresa le ha solicitado resolver es el de elaborar un sistema que les permita saber si el agua es potable o no. Para esto, la sanitaria les ha proveido una base de datos con la lectura de múltiples sensores IOT colocados en diversas cañerías, conductos y estanques. Estos sensores señalan nueve tipos de mediciones químicas y más una etiqueta elaborada en laboratorio que indica si el agua es potable o no el agua.
#
# La idea final es que puedan, en el caso que el agua no sea potable, dar un aviso inmediato para corregir el problema. Tenga en cuenta que parte del equipo docente vive en Maipú y su intoxicación podría implicar graves problemas para el cierre del curso.
#
# Atributos:
#
# 1. pH value
# 2. Hardness
# 3. Solids (Total dissolved solids - TDS)
# 4. Chloramines
# 5. Sulfate
# 6. Conductivity
# 7. Organic_carbon
# 8. Trihalomethanes
# 9. Turbidity
#
# Variable a predecir:
#
# 10. Potability (1 si es potable, 0 no potable)
#
# Descripción de cada atributo se pueden encontrar en el siguiente link: [dataset](https://www.kaggle.com/adityakadiwal/water-potability)

# %% [markdown]
# # **1. Optimización de modelos con Optuna + MLFlow (2.0 puntos)**
#
# El objetivo de esta sección es que ustedes puedan combinar Optuna con MLFlow para poder realizar la optimización de los hiperparámetros de sus modelos.
#
# Como aún no hemos hablado nada sobre `MLFlow` cabe preguntarse: **¡¿Qué !"#@ es `MLflow`?!**
#
# <p align="center">
#   <img src="https://media.tenor.com/eusgDKT4smQAAAAC/matthew-perry-chandler-bing.gif" width="400">
# </p>
#
# ## **MLFlow**
#
# `MLflow` es una plataforma de código abierto que simplifica la gestión y seguimiento de proyectos de aprendizaje automático. Con sus herramientas, los desarrolladores pueden organizar, rastrear y comparar experimentos, además de registrar modelos y controlar versiones.
#
# <p align="center">
#   <img src="https://spark.apache.org/images/mlflow-logo.png" width="350">
# </p>
#
# Si bien esta plataforma cuenta con un gran número de herramientas y funcionalidades, en este laboratorio trabajaremos con dos:
# 1. **Runs**: Registro que constituye la información guardada tras la ejecución de un entrenamiento. Cada `run` tiene su propio run_id, el cual sirve como identificador para el entrenamiento en sí mismo. Dentro de cada `run` podremos acceder a información como los hiperparámetros utilizados, las métricas obtenidas, las librerías requeridas y hasta nos permite descargar el modelo entrenado.
# 2. **Experiments**: Se utilizan para agrupar y organizar diferentes ejecuciones de modelos (`runs`). En ese sentido, un experimento puede agrupar 1 o más `runs`. De esta manera, es posible también registrar métricas, parámetros y archivos (artefactos) asociados a cada experimento.
#
# ### **Todo bien pero entonces, ¿cómo se usa en la práctica `MLflow`?**
#
# Es sencillo! Considerando un problema de machine learning genérico, podemos registrar la información relevante del entrenamiento ejecutando `mlflow.autolog()` antes entrenar nuestro modelo. Veamos este bonito ejemplo facilitado por los mismos creadores de `MLflow`:
#
# ```python
# #!pip install mlflow
# import mlflow # importar mlflow
#
# from sklearn.model_selection import train_test_split
# from sklearn.datasets import load_diabetes
# from sklearn.ensemble import RandomForestRegressor
#
#
# X_train, X_test, y_train, y_test = train_test_split(df_x, df_y)
#
# # Create and train models.
# rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
#
# mlflow.autolog() # registrar automáticamente información del entrenamiento
# with mlflow.start_run(): # delimita inicio y fin del run
#     # aquí comienza el run
#     rf.fit(X_train, y_train) # train the model
#     predictions = rf.predict(X_test) # Use the model to make predictions on the test dataset.
#     # aquí termina el run
# ```
#
# Si ustedes ejecutan el código anterior en sus máquinas locales (desde un jupyter notebook por ejemplo) se darán cuenta que en su directorio *root* se ha creado la carpeta `mlruns`. Esta carpeta lleva el tracking de todos los entrenamientos ejecutados desde el directorio root (importante: si se cambian de directorio y vuelven a ejecutar el código anterior, se creará otra carpeta y no tendrán acceso al entrenamiento anterior). Para visualizar estos entrenamientos, `MLflow` nos facilita hermosa interfaz visual a la que podemos acceder ejecutando:
#
# ```
# mlflow ui
# ```
#
# y luego pinchando en la ruta http://127.0.0.1:5000 que nos retorna la terminal. Veamos en vivo algunas de sus funcionalidades!
#
# <p align="center">
#   <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZXVuM3A5MW1heDFpa21qbGlwN2pyc2VoNnZsMmRzODZxdnluemo2bCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3o84sq21TxDH6PyYms/giphy.gif" width="400">
# </p>
#
# Les dejamos también algunos comandos útiles:
#
# - `mlflow.create_experiment("nombre_experimento")`: Les permite crear un nuevo experimento para agrupar entrenamientos
# - `mlflow.log_metric("nombre_métrica", métrica)`: Les permite registrar una métrica *custom* bajo el nombre de "nombre_métrica"

# %% [markdown]
# ## **1.1 Combinando Optuna + MLflow**
#
# Ahora que tenemos conocimiento de ambas herramientas, intentemos ahora combinarlas para **más sabor**. El objetivo de este apartado es simple: automatizar la optimización de los parámetros de nuestros modelos usando `Optuna` y registrando de forma automática cada resultado en `MLFlow`.
#
# Considerando el objetivo planteado, se le pide completar la función `optimize_model`, la cual debe:
# - **Optimizar los hiperparámetros del modelo `XGBoost` usando `Optuna`.**
# - **Registrar cada entrenamiento en un experimento nuevo**, asegurándose de que la métrica `mean absolute error` se registre como `"valid_mae"`. No se deben guardar todos los experimentos en *Default*; en su lugar, cada `experiment` y `run` deben tener nombres interpretables, reconocibles y diferentes a los nombres por defecto (por ejemplo, para un run: "XGBoost con lr 0.1").
# - **Guardar los gráficos de Optuna** dentro de una carpeta de artefactos de Mlflow llamada `/plots`.
# - **Devolver el mejor modelo** usando la función `get_best_model` y serializarlo en el disco con `pickle.dump`. Luego, guardar el modelo en la carpeta `/models`.
# - **Guardar el código en `optimize.py`**. La ejecución de `python optimize.py` debería ejecutar la función `optimize_model`.
# - **Guardar las versiones de las librerías utilizadas** en el desarrollo.
# - **Respalde las configuraciones del modelo final y la importancia de las variables** en un gráfico dentro de la carpeta `/plots` creada anteriormente.
#
# *Hint: Le puede ser útil revisar los parámetros que recibe `mlflow.start_run`*
#
# import mlflow # importar mlflow
#
# from sklearn.model_selection import train_test_split
# from sklearn.datasets import load_diabetes
# from sklearn.ensemble import RandomForestRegressor
#
#
# X_train, X_test, y_train, y_test = train_test_split(df_x, df_y)
#
# # Create and train models.
# rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
#
# mlflow.autolog() # registrar automáticamente información del entrenamiento
# with mlflow.start_run(): # delimita inicio y fin del run
#     # aquí comienza el run
#     rf.fit(X_train, y_train) # train the model
#     predictions = rf.predict(X_test) # Use the model to make predictions on the test dataset.
#     # aquí termina el run
#
#
# ```python
# def get_best_model(experiment_id):
#     runs = mlflow.search_runs(experiment_id)
#     best_model_id = runs.sort_values("metrics.valid_mae")["run_id"].iloc[0]
#     best_model = mlflow.sklearn.load_model("runs:/" + best_model_id + "/model")
#
#     return best_model
# ```

# %%
### 1
import mlflow
import mlflow.xgboost
import xgboost as xgb
import optuna
import pickle
import os
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

import pandas as pd

path = 'water_potability.csv'
df = pd.read_csv(path, sep=',')
promedios = df.mean()

# Reemplazar los valores nulos por el promedio de cada columna
df.fillna(promedios, inplace=True)

df_x = df.drop(columns=['Potability'])

df_y = df['Potability']

X_train, X_test, y_train, y_test = train_test_split(df_x, df_y,test_size=0.2, random_state=42)

# Configurar el directorio para los artefactos
artifacts_dir = "mlruns/artifacts"
os.makedirs(artifacts_dir, exist_ok=True)

# Definir la función de optimización
def objective(trial):
    # Sugerir valores para los hiperparámetros
    params = {
        "booster": "gbtree",
        "verbosity": 0,
        "objective": "reg:squarederror",
        "eval_metric": "mae",
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
        "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
    }

    # Crear y entrenar el modelo
    model = xgb.XGBRegressor(**params)
    model.fit(X_train, y_train)

    # Predecir y calcular el error absoluto medio
    y_pred = model.predict(X_test)
    valid_mae = mean_absolute_error(y_test, y_pred)
    
    # Registrar los resultados en MLflow
    with mlflow.start_run():
        mlflow.log_params(params)
        mlflow.log_metric("valid_mae", valid_mae)
    
    return valid_mae

# Optimizar el modelo con Optuna
def optimize_model():
    # Crear un estudio de Optuna
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=50)

    # Obtener el mejor modelo
    best_trial = study.best_trial
    best_model = xgb.XGBRegressor(**best_trial.params)
    best_model.fit(X_train, y_train)

    # Guardar el mejor modelo
    model_path = "models/best_model.pkl"
    with open(model_path, "wb") as f:
        pickle.dump(best_model, f)
    
    # Guardar los gráficos de Optuna en MLflow
    optuna.visualization.plot_optimization_history(study).write_image(f"{artifacts_dir}/optimization_history.png")
    optuna.visualization.plot_param_importances(study).write_image(f"{artifacts_dir}/param_importances.png")

    # Guardar la importancia de las características
    plt.figure(figsize=(10, 6))
    xgb.plot_importance(best_model, importance_type="weight")
    plt.savefig(f"{artifacts_dir}/feature_importance.png")
    plt.close()

    # Registrar las versiones de las librerías
    mlflow.log_artifacts(artifacts_dir)
    mlflow.set_tag("mlflow.version", mlflow.__version__)
    mlflow.set_tag("optuna.version", optuna.__version__)
    mlflow.set_tag("xgboost.version", xgb.__version__)

    return best_model

if __name__ == "__main__":
    best_model = optimize_model()
# Out:
# [I 2024-07-05 04:22:17,833] A new study created in memory with name: no-name-a112296d-aaed-4621-a3c9-3f54e65f53a4
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3cb99b6a2094434097d8388964ebe1ab', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:21] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:22,827] Trial 0 finished with value: 0.4720069802388912 and parameters: {'max_depth': 5, 'learning_rate': 0.00013794423954311744, 'n_estimators': 410, 'subsample': 0.6733272464707607, 'colsample_bytree': 0.6539283498925239}. Best is trial 0 with value: 0.4720069802388912.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ddd9c4b4a9264e3fa4eabe917650ed84', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:25 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:25] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:26,799] Trial 1 finished with value: 0.46862394108277994 and parameters: {'max_depth': 6, 'learning_rate': 0.0004692379138953585, 'n_estimators': 265, 'subsample': 0.880722824024525, 'colsample_bytree': 0.953809075189555}. Best is trial 1 with value: 0.46862394108277994.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '46388a586ae64239b7142a12cf26a6e7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:29 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:29] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:30,387] Trial 2 finished with value: 0.41269162275385474 and parameters: {'max_depth': 9, 'learning_rate': 0.04473806270946781, 'n_estimators': 150, 'subsample': 0.6880941118802586, 'colsample_bytree': 0.968287702770122}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:30 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a5d1a3954cf74d88b3f604ce8d61682a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:31] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:33,048] Trial 3 finished with value: 0.42793168871459075 and parameters: {'max_depth': 8, 'learning_rate': 0.03261247886378195, 'n_estimators': 77, 'subsample': 0.651200782513153, 'colsample_bytree': 0.9031755736583211}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ca5873c323b54d24951aa7739f1b0e40', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:34 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:34] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:35,741] Trial 4 finished with value: 0.42782842674258553 and parameters: {'max_depth': 4, 'learning_rate': 0.04778473859742057, 'n_estimators': 147, 'subsample': 0.9595385689684195, 'colsample_bytree': 0.7997542929155987}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:35 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'd375a8ef3315461eaa6ba3ca36ae46e7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:36 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:36] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:38,108] Trial 5 finished with value: 0.471819272855433 and parameters: {'max_depth': 5, 'learning_rate': 0.0006361895860427755, 'n_estimators': 65, 'subsample': 0.9349608007455885, 'colsample_bytree': 0.9260449029950637}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:38 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8230b05c5bd34a6c9e8be9fa158da44d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:42 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:42] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:44,169] Trial 6 finished with value: 0.41677137231170314 and parameters: {'max_depth': 9, 'learning_rate': 0.027873639241437626, 'n_estimators': 397, 'subsample': 0.6577182554675002, 'colsample_bytree': 0.8414651473220186}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:44 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '4e6cae6b95a1407ab4b6627468eaa960', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:47 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:47] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:49,348] Trial 7 finished with value: 0.46797470071512026 and parameters: {'max_depth': 9, 'learning_rate': 0.0004669324633871725, 'n_estimators': 282, 'subsample': 0.7075102534802866, 'colsample_bytree': 0.8568028351978947}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:49 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5b1bea9d927d4972a51d3c80a920766c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:54 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:54] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:55,881] Trial 8 finished with value: 0.4707185941771036 and parameters: {'max_depth': 10, 'learning_rate': 0.0002942184010036386, 'n_estimators': 340, 'subsample': 0.6089744551999827, 'colsample_bytree': 0.6637958687602644}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:55 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '45082946069c44a28202a8f1cce94335', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:22:57 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:22:57] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:22:59,037] Trial 9 finished with value: 0.45044765598708536 and parameters: {'max_depth': 5, 'learning_rate': 0.009164172849070066, 'n_estimators': 128, 'subsample': 0.6068042836203729, 'colsample_bytree': 0.8668348834817017}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:22:59 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '84ef374ca71a4a48a9d792687ee900c2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:03 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:03] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:05,222] Trial 10 finished with value: 0.45107127946415326 and parameters: {'max_depth': 7, 'learning_rate': 0.0037069911909840517, 'n_estimators': 500, 'subsample': 0.7955174039061487, 'colsample_bytree': 0.5184303357692865}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a6ef9aba801b40039ed37d209b919907', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:08] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:09,506] Trial 11 finished with value: 0.41465559879494635 and parameters: {'max_depth': 10, 'learning_rate': 0.07794669430929675, 'n_estimators': 188, 'subsample': 0.50220292511737, 'colsample_bytree': 0.9737288893813016}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:09 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0a15fe4f89a24c329ff04e5a07591f89', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:12 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:12] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:13,668] Trial 12 finished with value: 0.41614838447577956 and parameters: {'max_depth': 10, 'learning_rate': 0.0812310922081381, 'n_estimators': 189, 'subsample': 0.5261391336732136, 'colsample_bytree': 0.9850853854001685}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:13 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b8a9db6fdaa24e06ab1c84a259b86837', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:16] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:17,479] Trial 13 finished with value: 0.42719144704638096 and parameters: {'max_depth': 8, 'learning_rate': 0.010569184038572689, 'n_estimators': 215, 'subsample': 0.5114429863698527, 'colsample_bytree': 0.9982519284338888}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ee93220e83b74795836632e58f4f956b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:20 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:20] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:21,668] Trial 14 finished with value: 0.41501944158907705 and parameters: {'max_depth': 10, 'learning_rate': 0.08620310842393503, 'n_estimators': 196, 'subsample': 0.8084945491584394, 'colsample_bytree': 0.7348651525501333}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:21 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '84b2584ed7ce47ac8c761618393bb3cc', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:23] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:24,939] Trial 15 finished with value: 0.43928908681633266 and parameters: {'max_depth': 9, 'learning_rate': 0.012690790472881184, 'n_estimators': 139, 'subsample': 0.5698712126866836, 'colsample_bytree': 0.7434059125115234}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:24 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7a55899ea13f4f9aad0046a66dd45a9e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:27 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:27] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:29,203] Trial 16 finished with value: 0.44397904680723826 and parameters: {'max_depth': 8, 'learning_rate': 0.003500390788723333, 'n_estimators': 255, 'subsample': 0.7487137133923667, 'colsample_bytree': 0.9156655881066815}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e196b4405a2c490ab7aa3bbb4b2ca392', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:30 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:30] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:31,892] Trial 17 finished with value: 0.4713537723916333 and parameters: {'max_depth': 3, 'learning_rate': 0.001473650890502684, 'n_estimators': 120, 'subsample': 0.859294679175471, 'colsample_bytree': 0.5239006459393267}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e51491a263494d28a47d8d07da9ccb5e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:35 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:35] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:36,310] Trial 18 finished with value: 0.4152371077344003 and parameters: {'max_depth': 7, 'learning_rate': 0.01855091203634262, 'n_estimators': 313, 'subsample': 0.5717882705170195, 'colsample_bytree': 0.7848920978118142}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ef9ad0e3d51d4ed3b95ff97442219e95', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:39] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:40,459] Trial 19 finished with value: 0.4232707786327299 and parameters: {'max_depth': 9, 'learning_rate': 0.04772186400388553, 'n_estimators': 222, 'subsample': 0.733136172312994, 'colsample_bytree': 0.6638190781558277}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:40 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '95ee1de1e1324115824c0821384c0378', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:43] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:44,320] Trial 20 finished with value: 0.4217711558108354 and parameters: {'max_depth': 10, 'learning_rate': 0.08789902675451003, 'n_estimators': 179, 'subsample': 0.5012263143335388, 'colsample_bytree': 0.5967039222571716}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:44 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '89e082a924de4d3a8b4fc29d2b1be583', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:47 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:47] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:48,624] Trial 21 finished with value: 0.41380180391044585 and parameters: {'max_depth': 10, 'learning_rate': 0.09811549921940532, 'n_estimators': 206, 'subsample': 0.8020208382196579, 'colsample_bytree': 0.7320341737116858}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:48 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3e329aeb11784433b60f0f34d34ff086', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:23:50 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:23:50] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:23:51,827] Trial 22 finished with value: 0.41886166854557105 and parameters: {'max_depth': 10, 'learning_rate': 0.0457775171788946, 'n_estimators': 104, 'subsample': 0.7966534825783083, 'colsample_bytree': 0.7863636436764976}. Best is trial 2 with value: 0.41269162275385474.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:23:51 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '65f7a9e8a61a42a0bda5ea5871400c40', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# ...
# 2024/07/05 04:25:24 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '5bf0e216c4794b3fa92cf72cebc7a4a3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:28] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:29,429] Trial 42 finished with value: 0.408924049515385 and parameters: {'max_depth': 6, 'learning_rate': 0.062318192535215804, 'n_estimators': 378, 'subsample': 0.6742593191039342, 'colsample_bytree': 0.9980597224917562}. Best is trial 35 with value: 0.40591277611312715.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:25:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0a020b31105d4ae2b5c519c2b7d842c3', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:31] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:33,098] Trial 43 finished with value: 0.4155640144400844 and parameters: {'max_depth': 4, 'learning_rate': 0.028045401742644277, 'n_estimators': 340, 'subsample': 0.6319941952540648, 'colsample_bytree': 0.9896350664762109}. Best is trial 35 with value: 0.40591277611312715.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:25:33 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'bf419d3da096460bae63ed01bde1ab97', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:35 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:35] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:36,762] Trial 44 finished with value: 0.4065395856184584 and parameters: {'max_depth': 5, 'learning_rate': 0.061113182097464774, 'n_estimators': 304, 'subsample': 0.6494103004896123, 'colsample_bytree': 0.9729290479854712}. Best is trial 35 with value: 0.40591277611312715.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:25:36 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '9dd962cb385540f7a026bd24956a0ce4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:38 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:38] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:39,903] Trial 45 finished with value: 0.4718600322106263 and parameters: {'max_depth': 4, 'learning_rate': 0.00015698569928950648, 'n_estimators': 298, 'subsample': 0.6469911138387223, 'colsample_bytree': 0.9754795943446626}. Best is trial 35 with value: 0.40591277611312715.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:25:39 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'ab559e29803a40f0b668c85a7b73668f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:42 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:42] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:43,776] Trial 46 finished with value: 0.4070677656818589 and parameters: {'max_depth': 5, 'learning_rate': 0.0650302205948072, 'n_estimators': 329, 'subsample': 0.605236335979745, 'colsample_bytree': 0.995480013785999}. Best is trial 35 with value: 0.40591277611312715.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:25:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'b453f06457644e9d8ac9bb5d4c84b15a', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:46 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:46] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:47,266] Trial 47 finished with value: 0.4077104193331651 and parameters: {'max_depth': 5, 'learning_rate': 0.058979113989905275, 'n_estimators': 276, 'subsample': 0.596927332244798, 'colsample_bytree': 0.9976304915910315}. Best is trial 35 with value: 0.40591277611312715.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:25:47 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '65af28fd8c2241f39ec2863e7aeed5ca', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:49] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:50,683] Trial 48 finished with value: 0.41061042786345864 and parameters: {'max_depth': 5, 'learning_rate': 0.06483453096894291, 'n_estimators': 289, 'subsample': 0.5874042245785858, 'colsample_bytree': 0.9720818307235933}. Best is trial 35 with value: 0.40591277611312715.
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:40: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 1e-1),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:42: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
# /var/folders/kw/_g4nm_m11vd8530g9t7gvv180000gn/T/ipykernel_44247/2173255088.py:43: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0)
# 2024/07/05 04:25:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3d68e394dfb549b196b2605ed7f67169', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:53 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:53] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# [I 2024-07-05 04:25:54,573] Trial 49 finished with value: 0.41065842730756963 and parameters: {'max_depth': 5, 'learning_rate': 0.041577944079843415, 'n_estimators': 324, 'subsample': 0.5539233559334694, 'colsample_bytree': 0.9990101297462943}. Best is trial 35 with value: 0.40591277611312715.
# 2024/07/05 04:25:54 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'dc24717b1de74460a86c8ea920ea1bc0', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 2024/07/05 04:25:58 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/piaal/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [04:25:58] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified."
# 2024/07/05 04:26:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '814ac42df4e74a65a034f59bb9c12e1c', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %%
# !pip install "fastapi[all]"
# Out:
# Collecting fastapi[all]
#   Downloading fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi[all])
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from fastapi[all]) (1.10.15)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from fastapi[all]) (4.9.0)
# Collecting fastapi-cli>=0.0.2 (from fastapi[all])
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: httpx>=0.23.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from fastapi[all]) (0.26.0)
# Requirement already satisfied: jinja2>=2.11.2 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from fastapi[all]) (3.1.2)
# Collecting python-multipart>=0.0.7 (from fastapi[all])
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi[all])
#   Downloading ujson-5.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.3 kB)
# Requirement already satisfied: orjson>=3.2.1 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from fastapi[all]) (3.10.3)
# Collecting email_validator>=2.0.0 (from fastapi[all])
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0->fastapi[all])
#   Downloading uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: itsdangerous>=1.1.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from fastapi[all]) (2.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from fastapi[all]) (6.0.1)
# Collecting pydantic-settings>=2.0.0 (from fastapi[all])
#   Downloading pydantic_settings-2.3.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[all])
#   Downloading pydantic_extra_types-2.9.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi[all])
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from email_validator>=2.0.0->fastapi[all]) (3.4)
# Collecting typer>=0.12.3 (from fastapi-cli>=0.0.2->fastapi[all])
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio in /Users/piaal/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi[all]) (4.2.0)
# Requirement already satisfied: certifi in /Users/piaal/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi[all]) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/piaal/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi[all]) (1.0.2)
# Requirement already satisfied: sniffio in /Users/piaal/anaconda3/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi[all]) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi[all]) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from jinja2>=2.11.2->fastapi[all]) (2.1.5)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi[all])
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi[all]) (0.6.0)
# Collecting pydantic-core==2.20.1 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi[all])
#   Downloading pydantic_core-2.20.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from pydantic-settings>=2.0.0->fastapi[all]) (1.0.0)
# Requirement already satisfied: click>=7.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from uvicorn>=0.12.0->uvicorn[standard]>=0.12.0->fastapi[all]) (8.1.7)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi[all])
#   Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi[all])
#   Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi[all])
#   Downloading watchfiles-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0->fastapi[all])
#   Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi[all]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi[all]) (13.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi[all]) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/piaal/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi[all]) (0.1.2)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Downloading pydantic_extra_types-2.9.0-py3-none-any.whl (30 kB)
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 1.3 MB/s eta 0:00:0000:0100:01
# Downloading pydantic_core-2.20.1-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading pydantic_settings-2.3.4-py3-none-any.whl (22 kB)
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 1.4 MB/s eta 0:00:0000:01
# Downloading ujson-5.10.0-cp311-cp311-macosx_11_0_arm64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.3 MB/s eta 0:00:0000:01
# Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 800.2 kB/s eta 0:00:00a 0:00:01
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 1.4 MB/s eta 0:00:0000:0100:01m
# Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 kB 896.5 kB/s eta 0:00:000:010:01
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading watchfiles-0.22.0-cp311-cp311-macosx_11_0_arm64.whl (391 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.2/391.2 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Downloading websockets-12.0-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 1.8 MB/s eta 0:00:00 0:00:01
# Installing collected packages: websockets, uvloop, uvicorn, ujson, python-multipart, pydantic-core, httptools, dnspython, watchfiles, starlette, pydantic, email_validator, typer, pydantic-settings, pydantic-extra-types, fastapi-cli, fastapi
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.15
#     Uninstalling pydantic-1.10.15:
#       Successfully uninstalled pydantic-1.10.15
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.4.2 which is incompatible.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# dataprep 0.4.1 requires dask[array,dataframe,delayed]<3.0,>=2.25, but you have dask 2024.5.1 which is incompatible.
# dataprep 0.4.1 requires flask<2.0.0,>=1.1.4, but you have flask 3.0.3 which is incompatible.
# dataprep 0.4.1 requires jinja2<3.0,>=2.11, but you have jinja2 3.1.2 which is incompatible.
# dataprep 0.4.1 requires pydantic<2.0,>=1.6, but you have pydantic 2.8.2 which is incompatible.
# dataprep 0.4.1 requires regex<2021.0.0,>=2020.10.15, but you have regex 2024.5.10 which is incompatible.
# Successfully installed dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 httptools-0.6.1 pydantic-2.8.2 pydantic-core-2.20.1 pydantic-extra-types-2.9.0 pydantic-settings-2.3.4 python-multipart-0.0.9 starlette-0.37.2 typer-0.12.3 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import necessary libraries
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix
import lightgbm as lgb
import optuna
import mlflow
import mlflow.lightgbm
import requests
import json

# %% [markdown]
# # **2. FastAPI (2.0 puntos)**
#
# <div align="center">
#   <img src="https://media3.giphy.com/media/YQitE4YNQNahy/giphy-downsized-large.gif" width="500">
# </div>
#
# Con el modelo ya entrenado, la idea de esta sección es generar una API REST a la cual se le pueda hacer *requests* para así interactuar con su modelo. En particular, se le pide:
#
# - Guardar el código de esta sección en el archivo `main.py`. Note que ejecutar `python main.py` debería levantar el servidor en el puerto por defecto.
# - Defina `GET` con ruta tipo *home* que describa brevemente su modelo, el problema que intenta resolver, su entrada y salida.
# - Defina un `POST` a la ruta `/potabilidad/` donde utilice su mejor optimizado para predecir si una medición de agua es o no potable. Por ejemplo, una llamada de esta ruta con un *body*:
#
# ```json
# {
#    "ph":10.316400384553162,
#    "Hardness":217.2668424334475,
#    "Solids":10676.508475429378,
#    "Chloramines":3.445514571005745,
#    "Sulfate":397.7549459751925,
#    "Conductivity":492.20647361771086,
#    "Organic_carbon":12.812732207582542,
#    "Trihalomethanes":72.28192021570328,
#    "Turbidity":3.4073494284238364
# }
# ```
#
# Su servidor debería retornar una respuesta HTML con código 200 con:
#
#
# ```json
# {
#   "potabilidad": 0 # respuesta puede variar según el clasificador que entrenen
# }
# ```

# %%
### 2

# URL de la API
api_url = 'http://127.0.0.1:8000/potability/'

# Datos para la predicción
data = {
    "pH": 10.316400384553162,
    "Hardness": 217.2668424334475,
    "Solids": 10676.508475429378,
    "Chloramines": 3.445514571005745,
    "Sulfate": 397.7549459751925,
    "Conductivity": 492.20647361771086,
    "Organic_carbon": 12.812732207582542,
    "Trihalomethanes": 72.28192021570328,
    "Turbidity": 3.4073494284238364
}

# Realizar la solicitud POST
response = requests.post(api_url, json=data)

# Mostrar la respuesta
if response.status_code == 200:
    result = response.json()
    print(f"Predicción de potabilidad: {result['potability']}")
else:
    print(f"Error al realizar la solicitud: {response.status_code}")
# Out:
# Predicción de potabilidad: 0

# %% [markdown]
# # **3. Docker (2 puntos)**

# %% [markdown]
# <div align="center">
#   <img src="https://miro.medium.com/v2/resize:fit:1400/1*9rafh2W0rbRJIKJzqYc8yA.gif" width="500">
# </div>

# %% [markdown]
# Tras el éxito de su aplicación web para generar la salida, Smapina le solicita que genere un contenedor para poder ejecutarla en cualquier computador de la empresa de agua potable.
#
# ## **3.1 Creación de Container (1 punto)**
#
# Cree un Dockerfile que use una imagen base de Python, copie los archivos del proyecto e instale las dependencias desde un `requirements.txt`. Con esto, construya y ejecute el contenedor Docker para la API configurada anteriormente. Entregue el código fuente (incluyendo `main.py`, `requirements.txt`, y `Dockerfile`) y la imagen Docker de la aplicación. Para la dockerización, asegúrese de cumplir con los siguientes puntos:
#
# 1. **Generar un archivo `.dockerignore`** que ignore carpetas y archivos innecesarios dentro del contenedor.
# 2. **Configurar un volumen** que permita la persistencia de los datos en una ruta local del computador.
# 3. **Exponer el puerto** para acceder a la ruta de la API sin tener que entrar al contenedor directamente.
# 4. **Incluir imágenes en el notebook** que muestren la ejecución del contenedor y los resultados obtenidos.
# 5. **Revisar y comentar los recursos utilizados por el contenedor**. Analice si los contenedores son livianos en términos de recursos.
#
# Al verificar el uso de recursos desde Monitor de Actividad en relación al uso de CPU y memoria notamos que el contenedor es "liviano" en términos de recursos ya que su ejecución no marca peaks considerables en los recursos. Además, el tamaño del contenedor en el disco no es grande dado que el programa de la aplicación es básico.
#
# Otro punto a destacar es la opción de asignar y distribuir recursos directamente desde las preferencias de docker.
#
# Considerando que las dependencias y capas de la imagen de docker son básicas y mínimas, el contenedor es bastante liviano y rápido de ejecutar.

# %% [markdown]
# ## **3.2 Preguntas de Smapina (1 punto)**
# Tras haber experimentado con Docker, Smapina desea profundizar más en el tema y decide realizarle las siguientes consultas:
#
# - **¿Cómo se diferencia Docker de una máquina virtual (VM)?**
#
# Si bien ambas son tecnologías de virtualización, Docker es una plataforma de contenedores que permite "empaquetar" las aplicaciones y sus dependencias (librerias o modulos de python) en contenedores ligeros y portátiles, ejecutándose sobre el mismo sistema operativo anfitrión con una sobrecarga mínima. Por otro lado, una maquina virtual incluye un sistema operativo completo (como Linux, Windows, MacOS, etc) junto con la aplicación y sus dependencias, ejecutándose sobre un hipervisor (monitor de máquina virtual) que virtualiza el hardware del anfitrión. Lo anterior hace  Esto hace que las VMs sean más pesadas en términos de recursos y más lentas para iniciar, pero proporcionan un aislamiento más fuerte, ya que cada VM opera de manera independiente con su propio sistema operativo completo.
#
# - **¿Cuál es la diferencia entre usar Docker y ejecutar la aplicación directamente en el sistema local?**
#
# La principal diferencia entre usar Docker y ejecutar una aplicación directamente en local es principalmente la portabilidad y el aislamiento. Docker permite empaquetar una aplicación junto con todas sus dependencias en un contenedor que permite que funcione consistentemente en cualquier entorno, independientemente de las configuraciones del sistema anfitrión. Lo anterior, facilita la migración y el despliegue en diferentes servicios en la nube. En contraste, ejecutar la aplicación directamente en el sistema local puede llevar a problemas de compatibilidad y configuraciones específicas del entorno, lo que puede complicar la replicación y el mantenimiento en diferentes entornos de desarrollo y producción.
#
# - **¿Cómo asegura Docker la consistencia entre diferentes entornos de desarrollo y producción?**
#
# Docker asegura la consistencia entre diferentes entornos de desarrollo y producción al encapsular la aplicación y todas sus dependencias en contenedores. Estos contenedores incluyen todo lo necesario para ejecutar la aplicación, desde bibliotecas y configuraciones hasta el sistema operativo subyacente. Al usar imágenes de Docker para crear estos contenedores, se garantiza que la aplicación se ejecutará de la misma manera en cualquier entorno que soporte Docker, eliminando problemas de "funciona en mi máquina". Esto resulta en un comportamiento predecible y replicable, independientemente del entorno donde se despliegue la aplicación.
#
# - **¿Cómo se gestionan los volúmenes en Docker para la persistencia de datos?**
#
# En Docker los volúmenes se usan para gestionar la persistencia de datos (almacenamiento de forma duradera y accesible a lo largo del tiempo) permitiendo que los datos sobrevivan a los ciclos de vida de los contenedores. Los volúmenes son "directorios" en el sistema de archivos del anfitrión donde se montan en los contenedores, proporcionando una manera eficiente de almacenar datos fuera del contenedor. Con esto se garantiza que los datos no se pierdan cuando un contenedor se elimina o se recrea. Los volúmenes pueden ser gestionados por Docker, lo que facilita la administración de los datos, respaldos y la compartición de datos entre contenedores.
#
#
# - **¿Qué son Dockerfile y docker-compose.yml, y cuál es su propósito?**
#
# El Dockerfile es un archivo de texto que contiene un conjunto de instrucciones para construir una imagen de Docker, especificando cómo debe configurarse el entorno de un contenedor, incluyendo el sistema operativo, las dependencias, el código de la aplicación y otros componentes necesarios. Por otro lado, el docker-compose.yml es un archivo de configuración en formato YAML utilizado por Docker Compose para definir y ejecutar aplicaciones multicontenedor. Este archivo describe los servicios, redes y volúmenes necesarios para la aplicación, permitiendo orquestar fácilmente múltiples contenedores y gestionar sus interacciones. Juntos, el Dockerfile y el docker-compose.yml facilitan la creación, despliegue y escalado de aplicaciones contenedorizadas de manera consistente y eficiente.

# %% [markdown]
# # Conclusión
# Eso ha sido todo para el lab de hoy, recuerden que el laboratorio tiene un plazo de entrega de una semana. Cualquier duda del laboratorio, no duden en contactarnos por mail o U-cursos.
#
# <div align="center">
#   <img src="https://i.pinimg.com/originals/84/5d/f1/845df1aefc6a5e37ae575327a0cc6e43.gif" width="500">
# </div>
